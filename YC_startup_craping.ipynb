# %% [markdown]
# # THIS PROGRAM AIMS TO SCRAPE STARTUPS FROM THE YC WEBSITE #
#
# ##APPROACH##
# We will be looking at the YC website. Depending on the ask, the program should cater towards a filter available by YC or by program. The steps for this project will be:
#
# - Observe the YC HTML elements
# - Recognize the patterns
# - Zoom into elements that can provide name of the company
# - Use the name of the company to go to YC’s company specific website
# - Scrape information
# - Rinse and repeat

# %%
# Set up for running selenium in Google Colab
## You don't need to run this code if you do it in Jupyter notebook, or other local Python setting
# %%shell
sudo apt -y update
sudo apt install -y wget curl unzip
wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
dpkg -i libu2f-udev_1.1.4-1_all.deb
wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
dpkg -i google-chrome-stable_current_amd64.deb
CHROME_DRIVER_VERSION=`curl -sS chromedriver.storage.googleapis.com/LATEST_RELEASE`
wget -N https://chromedriver.storage.googleapis.com/$CHROME_DRIVER_VERSION/chromedriver_linux64.zip -P /tmp/
unzip -o /tmp/chromedriver_linux64.zip -d /tmp/
chmod +x /tmp/chromedriver
mv /tmp/chromedriver /usr/local/bin/chromedriver
pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [830 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,756 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,037 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,077 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,371 kB]
# Fetched 7,306 kB in 6s (1,207 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 46 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# curl is already the newest version (7.81.0-1ubuntu1.16).
# unzip is already the newest version (6.0-26ubuntu3.2).
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.
# --2024-05-03 02:26:01--  http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 185.125.190.36, 91.189.91.82, 91.189.91.81, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|185.125.190.36|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3708 (3.6K) [application/x-debian-package]
# Saving to: ‘libu2f-udev_1.1.4-1_all.deb’
#
# libu2f-udev_1.1.4-1 100%[===================>]   3.62K  --.-KB/s    in 0s
#
# 2024-05-03 02:26:02 (144 MB/s) - ‘libu2f-udev_1.1.4-1_all.deb’ saved [3708/3708]
#
# Selecting previously unselected package libu2f-udev.
# (Reading database ... 121920 files and directories currently installed.)
# Preparing to unpack libu2f-udev_1.1.4-1_all.deb ...
# Unpacking libu2f-udev (1.1.4-1) ...
# Setting up libu2f-udev (1.1.4-1) ...
# --2024-05-03 02:26:03--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 108.177.125.190, 108.177.125.91, 108.177.125.136, ...
# Connecting to dl.google.com (dl.google.com)|108.177.125.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107002536 (102M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb’
#
# google-chrome-stabl 100%[===================>] 102.04M   185MB/s    in 0.6s
#
# 2024-05-03 02:26:03 (185 MB/s) - ‘google-chrome-stable_current_amd64.deb’ saved [107002536/107002536]
#
# Selecting previously unselected package google-chrome-stable.
# (Reading database ... 121924 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (124.0.6367.118-1) ...
# dpkg: dependency problems prevent configuration of google-chrome-stable:
#  google-chrome-stable depends on libvulkan1; however:
#   Package libvulkan1 is not installed.
#
# dpkg: error processing package google-chrome-stable (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for man-db (2.10.2-1) ...
# Errors were encountered while processing:
#  google-chrome-stable
# --2024-05-03 02:26:20--  https://chromedriver.storage.googleapis.com/114.0.5735.90/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 74.125.204.207, 64.233.187.207, 64.233.188.207, ...
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|74.125.204.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7407250 (7.1M) [application/zip]
# Saving to: ‘/tmp/chromedriver_linux64.zip’
#
# chromedriver_linux6 100%[===================>]   7.06M  6.77MB/s    in 1.0s
#
# 2024-05-03 02:26:22 (6.77 MB/s) - ‘/tmp/chromedriver_linux64.zip’ saved [7407250/7407250]
#
# Archive:  /tmp/chromedriver_linux64.zip
#   inflating: /tmp/chromedriver
#   inflating: /tmp/LICENSE.chromedriver
# Collecting selenium
#   Downloading selenium-4.20.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 50.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.25.0-py3-none-any.whl (467 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 29.1 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.20.0 trio-0.25.0 trio-websocket-0.11.1 wsproto-1.2.0

# %%
# !pip install chromedriver-autoinstaller
# Out:
# Collecting chromedriver-autoinstaller
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from chromedriver-autoinstaller) (24.0)
# Installing collected packages: chromedriver-autoinstaller
# Successfully installed chromedriver-autoinstaller-0.6.4

# %%
# Taken from: https://nariyoo.com/python-how-to-run-selenium-in-google-colab/

import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import chromedriver_autoinstaller
import re
import requests


chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') # ensure GUI is off
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# set path to chromedriver as per your configuration
chromedriver_autoinstaller.install()

# set up the webdriver
driver = webdriver.Chrome(options=chrome_options)

# %%
url = "https://www.ycombinator.com/companies/?batch=W24"
driver.get(url)

# %%
def page_load():
    """
    Loads the page. Scrolls down every two seconds.
    No parameters needed
    """
    last_height = driver.execute_script('return document.body.scrollHeight')
    while True:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)  # wait for new elements to load
        new_height = driver.execute_script('return document.body.scrollHeight')
        if new_height == last_height:
            break
        last_height = new_height

# %%
page_load()

# %%
source = driver.page_source

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
## Formatting company name to access YC company specific website

def replace(s):
    """Replaces any dots or spaces with -
    Param (company name)->string type

    Example:
    replace('InspectMind AI;)

    company = "voltage k"
    replace('voltage k)
    """
    return re.sub(r'[ .]', '-', s).lower()

# %%
## Parsing through [Company Name], [Location], [Description], [Category]
divs = soup.find_all('div', 'lg:max-w-[90%]')

## Taking company info and creating a web_name to iterate through later
company_info = []

for info in divs:
    name = info.find('span','_coName_99gj3_454').text
    location = info.find('span','_coLocation_99gj3_470').text
    descrip = info.find('span','_coDescription_99gj3_479').text

    dictionary = { 'Company': name,
                  'Location' : location,
                   'Description' : descrip,
                   'web_name' : replace(name)
    }

    company_info.append(dictionary)

# %%
df = pd.DataFrame(company_info)

# %%
df
# Out:
#                  Company                         Location  \
# 0               Alacrity           San Francisco, CA, USA
# 1              ParcelBio           San Francisco, CA, USA
# 2           K-Scale Labs                New York, NY, USA
# 3              Marr Labs           San Francisco, CA, USA
# 4          Forge Rewards           San Francisco, CA, USA
# ..                   ...                              ...
# 243              Lantern           San Francisco, CA, USA
# 244              Danswer
# 245                Yenmo             Bengaluru, KA, India
# 246            GovernGPT              Toronto, ON, Canada
# 247  Stitch Technologies  London, England, United Kingdom
#
#                                            Description             web_name
# 0        AI Based Account Takeover Prevention Platform             alacrity
# 1                       Next-generation mRNA medicines            parcelbio
# 2                          Open-source humanoid robots         k-scale-labs
# 3    AI-voice agents that are indistinguishable fro...            marr-labs
# 4    All-in-one operations software to power restau...        forge-rewards
# ..                                                 ...                  ...
# 243  Postgres vector database extension to build AI...              lantern
# 244     Open Source AI Assistant and Enterprise Search              danswer
# 245                  Secured consumer lending in India                yenmo
# 246                   AI Back Office for Private Funds            governgpt
# 247                                                  -  stitch-technologies
#
# [248 rows x 4 columns]

# %%
def find_emails(url):
    """ Finds email given a URL
    Param (url or "url")

    Examples:
    find_emails("https://www.ycombinator.com/companies/alacrity")

    url= "https://www.ycombinator.com/companies/alacrity"
    find_emails(url)
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'

    emails = list(re.findall(email_regex, soup.get_text()))

    return emails

# %%
## Testing
url = "https://www.ycombinator.com/companies/alacrity"

find_emails(url)
# Out:
# ['founders@joinalacrity.com']

# %%
## URL = https://www.ycombinator.com/companies/

list_founders = []
empty_sets = []

for index, data in df.iterrows():
    # Some companies might not have founders name
    # using try for code to keep running if founders name not found
    try:
        url = f"https://www.ycombinator.com/companies/{data['web_name']}"
        driver.get(url)
        iter_source = driver.page_source
        # Searching for elements
        soup2 = BeautifulSoup(iter_source, "html.parser")
        founders = soup2.find('div','space-y-5')
        comp = soup2.find('div', 'space-y-3')
        season = soup2.find('div', 'flex flex-row items-center gap-[6px]')
        tags = soup2.find_all('div', 'yc-tw-Pill rounded-sm bg-[#E6E4DC] uppercase tracking-widest px-3 py-[3px] text-[12px] font-thin')
        # Setting our identifiers
        comp_name = comp.find('h1', 'font-extralight').text
        founders_name = founders.find_all('h3', 'text-lg font-bold')
        cleaned_founders = [name.text for name in founders_name]
        linkedin_link = soup2.find('a', title='LinkedIn profile')['href']
        season_tag = season.find('span').text
        other_tags = [tag.text for tag in tags]
        # Organized dictionary
        fc_dic = {
            "URL": url,
            "Company" : comp_name,
            "Founders": cleaned_founders,
            "LinkedIn" : linkedin_link,
            "Season": season_tag,
            "Other Tags": other_tags,
            "Email": find_emails(url)
        }
        #Append dictionary to list
        list_founders.append(fc_dic)
        print('\x1b[6;30;42m' + 'Success!' + '\x1b[0m')
        print(f'{comp_name} has valid founder information. continue...')
    except:
        empty_sets.append(comp_name)
        print('\x1b[6;30;41m' + 'Error!' + '\x1b[0m')
        print(f'{comp_name} has empty information somwhere. continue...')
        continue

list_founders
# Out:
# Success!
# Alacrity has valid founder information. continue...
# Success!
# ParcelBio has valid founder information. continue...
# Success!
# K-Scale Labs has valid founder information. continue...
# Success!
# Marr Labs has valid founder information. continue...
# Success!
# Forge Rewards has valid founder information. continue...
# Success!
# FanCave has valid founder information. continue...
# Success!
# RetailReady has valid founder information. continue...
# Success!
# Million has valid founder information. continue...
# Success!
# NowHouse has valid founder information. continue...
# Success!
# Crux has valid founder information. continue...
# Success!
# Reprompt has valid founder information. continue...
# Success!
# InspectMind AI has valid founder information. continue...
# Error!
# InspectMind AI has empty information somwhere. continue...
# Success!
# Blacksmith has valid founder information. continue...
# Success!
# CrowdVolt has valid founder information. continue...
# Success!
# kater.ai has valid founder information. continue...
# Success!
# MathGPTPro has valid founder information. continue...
# Success!
# Quivr has valid founder information. continue...
# Success!
# Dragoneye has valid founder information. continue...
# Success!
# renderlet has valid founder information. continue...
# Success!
# Fume has valid founder information. continue...
# Success!
# Numo has valid founder information. continue...
# Success!
# Forge has valid founder information. continue...
# Success!
# Taiki has valid founder information. continue...
# Success!
# Konstructly has valid founder information. continue...
# Success!
# Pico has valid founder information. continue...
# Success!
# Granza Bio has valid founder information. continue...
# Success!
# Haplotype Labs has valid founder information. continue...
# Success!
# Healia has valid founder information. continue...
# Success!
# TrueClaim has valid founder information. continue...
# Success!
# CoCrafter has valid founder information. continue...
# Success!
# Reform has valid founder information. continue...
# Success!
# Piramidal has valid founder information. continue...
# Success!
# Junction Bioscience has valid founder information. continue...
# Success!
# OddsView has valid founder information. continue...
# Success!
# SiLogy has valid founder information. continue...
# Success!
# Senso has valid founder information. continue...
# Success!
# Eris Biotech has valid founder information. continue...
# Success!
# Powder has valid founder information. continue...
# Success!
# OpenFoundry has valid founder information. continue...
# Success!
# GoldenBasis has valid founder information. continue...
# Success!
# Arcane has valid founder information. continue...
# Success!
# Somn has valid founder information. continue...
# Success!
# Magic Hour has valid founder information. continue...
# Success!
# Ryse has valid founder information. continue...
# Success!
# Lumona has valid founder information. continue...
# Success!
# Datacurve has valid founder information. continue...
# Success!
# Marblism has valid founder information. continue...
# Success!
# CommodityAI has valid founder information. continue...
# Success!
# Veles has valid founder information. continue...
# Success!
# Miden has valid founder information. continue...
# Success!
# Fluently has valid founder information. continue...
# Success!
# Basepilot has valid founder information. continue...
# Success!
# Aqua Voice has valid founder information. continue...
# Success!
# Onedoc has valid founder information. continue...
# Success!
# xPay has valid founder information. continue...
# Success!
# DeepNight has valid founder information. continue...
# Success!
# Vista Space has valid founder information. continue...
# Success!
# Corefin has valid founder information. continue...
# Success!
# Ocular AI has valid founder information. continue...
# Success!
# Retell AI has valid founder information. continue...
# Success!
# Rove has valid founder information. continue...
# Success!
# camelQA has valid founder information. continue...
# Success!
# Spark has valid founder information. continue...
# Success!
# Titan has valid founder information. continue...
# Success!
# Terrakotta has valid founder information. continue...
# Success!
# Stacksync has valid founder information. continue...
# Success!
# Ecliptor has valid founder information. continue...
# Success!
# Shepherd has valid founder information. continue...
# Success!
# Sonauto has valid founder information. continue...
# Success!
# BiteSight has valid founder information. continue...
# Success!
# Velorum Therapeutics has valid founder information. continue...
# Success!
# Zep AI has valid founder information. continue...
# Success!
# Openmart has valid founder information. continue...
# Success!
# Triply has valid founder information. continue...
# Success!
# Amber AI has valid founder information. continue...
# Success!
# thorntale has valid founder information. continue...
# Success!
# Alai has valid founder information. continue...
# Success!
# PocketPod has valid founder information. continue...
# Success!
# Brainbase has valid founder information. continue...
# Success!
# Focal has valid founder information. continue...
# Success!
# Givefront has valid founder information. continue...
# Success!
# Cleva has valid founder information. continue...
# Success!
# Oma Care has valid founder information. continue...
# Success!
# Artos has valid founder information. continue...
# Success!
# Model ML has valid founder information. continue...
# Success!
# BetterBasket has valid founder information. continue...
# Success!
# Circleback has valid founder information. continue...
# Success!
# just words has valid founder information. continue...
# Success!
# Risotto has valid founder information. continue...
# Success!
# DianaHR has valid founder information. continue...
# Success!
# HeartByte has valid founder information. continue...
# Success!
# Yondu has valid founder information. continue...
# Success!
# dawn has valid founder information. continue...
# Success!
# Lumina has valid founder information. continue...
# Success!
# Centauri AI has valid founder information. continue...
# Success!
# ProSights has valid founder information. continue...
# Success!
# Manifold Freight has valid founder information. continue...
# Success!
# edgetrace has valid founder information. continue...
# Success!
# Clarum has valid founder information. continue...
# Success!
# Opencall.ai has valid founder information. continue...
# Success!
# Voicepanel has valid founder information. continue...
# Success!
# Skygaze has valid founder information. continue...
# Success!
# Abel has valid founder information. continue...
# Success!
# OffDeal has valid founder information. continue...
# Success!
# Delve has valid founder information. continue...
# Success!
# Andy AI has valid founder information. continue...
# Error!
# Andy AI has empty information somwhere. continue...
# Success!
# Shiboleth has valid founder information. continue...
# Success!
# Kontractify has valid founder information. continue...
# Success!
# Soundry AI has valid founder information. continue...
# Success!
# Elodin has valid founder information. continue...
# Success!
# HostAI has valid founder information. continue...
# Success!
# Trieve has valid founder information. continue...
# Success!
# Tensorfuse has valid founder information. continue...
# Success!
# Toma has valid founder information. continue...
# Success!
# Carma has valid founder information. continue...
# Success!
# Preloop has valid founder information. continue...
# Success!
# Superagent has valid founder information. continue...
# Success!
# Bilanc has valid founder information. continue...
# Success!
# SevnAI has valid founder information. continue...
# Success!
# Browser Buddy has valid founder information. continue...
# Success!
# Astro Mechanica has valid founder information. continue...
# Success!
# CodeAnt AI has valid founder information. continue...
# Success!
# Draftaid has valid founder information. continue...
# Success!
# Metofico has valid founder information. continue...
# Success!
# Ellipsis has valid founder information. continue...
# Success!
# Dime has valid founder information. continue...
# Success!
# SpareChange has valid founder information. continue...
# Error!
# SpareChange has empty information somwhere. continue...
# Success!
# Wuri has valid founder information. continue...
# Success!
# Opens has valid founder information. continue...
# Success!
# Aedilic has valid founder information. continue...
# Success!
# Salvy has valid founder information. continue...
# Success!
# Centralize has valid founder information. continue...
# Success!
# phospho has valid founder information. continue...
# Success!
# Quantic has valid founder information. continue...
# Success!
# Resonance has valid founder information. continue...
# Success!
# Firebender has valid founder information. continue...
# Success!
# Aether Energy has valid founder information. continue...
# Success!
# Kiosk has valid founder information. continue...
# Success!
# Ragas has valid founder information. continue...
# Success!
# sync labs has valid founder information. continue...
# Success!
# PandasAI has valid founder information. continue...
# Success!
# Infinity has valid founder information. continue...
# Success!
# TableFlow has valid founder information. continue...
# Success!
# Markprompt has valid founder information. continue...
# Success!
# Tamarind Bio has valid founder information. continue...
# Success!
# Anaphero has valid founder information. continue...
# Error!
# Anaphero has empty information somwhere. continue...
# Success!
# Intercept has valid founder information. continue...
# Success!
# Creo has valid founder information. continue...
# Success!
# Decipher AI has valid founder information. continue...
# Success!
# Infinity AI has valid founder information. continue...
# Success!
# Double – Coding Copilot has valid founder information. continue...
# Success!
# Speck has valid founder information. continue...
# Success!
# Guide Labs has valid founder information. continue...
# Success!
# OmniAI has valid founder information. continue...
# Success!
# Keywords AI has valid founder information. continue...
# Success!
# PromptArmor has valid founder information. continue...
# Success!
# Zaymo has valid founder information. continue...
# Success!
# Glimmer has valid founder information. continue...
# Success!
# Celest has valid founder information. continue...
# Success!
# Meticulate has valid founder information. continue...
# Success!
# CloudCruise has valid founder information. continue...
# Success!
# Attunement has valid founder information. continue...
# Success!
# Lucite has valid founder information. continue...
# Success!
# Selera Medical has valid founder information. continue...
# Success!
# OneGrep has valid founder information. continue...
# Success!
# Parasale has valid founder information. continue...
# Success!
# Tusk has valid founder information. continue...
# Success!
# PartnerHQ has valid founder information. continue...
# Success!
# atopile has valid founder information. continue...
# Success!
# Blume Benefits has valid founder information. continue...
# Success!
# Airfront has valid founder information. continue...
# Success!
# SynsoryBio has valid founder information. continue...
# Success!
# Yoneda Labs has valid founder information. continue...
# Success!
# TokenOwl has valid founder information. continue...
# Success!
# Hona has valid founder information. continue...
# Success!
# Topo has valid founder information. continue...
# Success!
# Trellis has valid founder information. continue...
# Success!
# Ecliptor has valid founder information. continue...
# Success!
# Greenboard has valid founder information. continue...
# Success!
# Eggnog has valid founder information. continue...
# Success!
# Artisan AI has valid founder information. continue...
# Success!
# Octolane AI has valid founder information. continue...
# Success!
# SuretyNow has valid founder information. continue...
# Success!
# Roe AI has valid founder information. continue...
# Success!
# Arini has valid founder information. continue...
# Success!
# Paradigm has valid founder information. continue...
# Success!
# PointOne has valid founder information. continue...
# Success!
# Patchwork has valid founder information. continue...
# Success!
# Starlight Charging has valid founder information. continue...
# Error!
# Assembly has empty information somwhere. continue...
# Success!
# MathDash has valid founder information. continue...
# Success!
# Leaping has valid founder information. continue...
# Success!
# Basalt Tech has valid founder information. continue...
# Success!
# Carousel Technologies has valid founder information. continue...
# Error!
# Carousel Technologies has empty information somwhere. continue...
# Success!
# DaLMatian has valid founder information. continue...
# Success!
# Pivot Robots has valid founder information. continue...
# Success!
# Aidy has valid founder information. continue...
# Success!
# DGI Apparel has valid founder information. continue...
# Success!
# Buster has valid founder information. continue...
# Success!
# Garage has valid founder information. continue...
# Success!
# Mango Health has valid founder information. continue...
# Error!
# Mango Health has empty information somwhere. continue...
# Success!
# nCompass Technologies has valid founder information. continue...
# Success!
# Pretzel AI has valid founder information. continue...
# Success!
# Apriora has valid founder information. continue...
# Success!
# malibou has valid founder information. continue...
# Success!
# Quary has valid founder information. continue...
# Success!
# Hemingway has valid founder information. continue...
# Success!
# Tile has valid founder information. continue...
# Success!
# Adagy Robotics has valid founder information. continue...
# Success!
# Momentic has valid founder information. continue...
# Success!
# Reducto has valid founder information. continue...
# Success!
# Vectorview has valid founder information. continue...
# Success!
# Maia has valid founder information. continue...
# Error!
# Maia has empty information somwhere. continue...
# Success!
# Precip has valid founder information. continue...
# Success!
# Tracecat has valid founder information. continue...
# Success!
# Kabilah has valid founder information. continue...
# Success!
# Sonia has valid founder information. continue...
# Success!
# MAIHEM has valid founder information. continue...
# Success!
# ion design has valid founder information. continue...
# Success!
# Duckie has valid founder information. continue...
# Success!
# Happenstance has valid founder information. continue...
# Success!
# Ubicloud has valid founder information. continue...
# Success!
# Greptile has valid founder information. continue...
# Success!
# HeyPurple has valid founder information. continue...
# Success!
# ego has valid founder information. continue...
# Success!
# Leya has valid founder information. continue...
# Success!
# Scritch has valid founder information. continue...
# Success!
# RadMate AI has valid founder information. continue...
# Success!
# ssoReady has valid founder information. continue...
# Success!
# Relari has valid founder information. continue...
# Success!
# DryMerge has valid founder information. continue...
# Success!
# Navier AI has valid founder information. continue...
# Success!
# Upsolve AI has valid founder information. continue...
# Success!
# SciPhi has valid founder information. continue...
# Success!
# AgentHub has valid founder information. continue...
# Success!
# Driver AI has valid founder information. continue...
# Success!
# Lantern has valid founder information. continue...
# Success!
# Danswer has valid founder information. continue...
# Success!
# Yenmo has valid founder information. continue...
# Success!
# GovernGPT has valid founder information. continue...
# Success!
# Stitch Technologies has valid founder information. continue...
# [{'URL': 'https://www.ycombinator.com/companies/alacrity',
#   'Company': 'Alacrity',
#   'Founders': ['Omar Draz', 'Anderthan Hsieh'],
#   'LinkedIn': 'https://www.linkedin.com/company/100487698/admin',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'identity',
#    'fraud-prevention',
#    'fraud-detection',
#    'San Francisco'],
#   'Email': ['founders@joinalacrity.com']},
#  {'URL': 'https://www.ycombinator.com/companies/parcelbio',
#   'Company': 'ParcelBio',
#   'Founders': ['David Weinberg', 'Chris Carlson'],
#   'LinkedIn': 'https://www.linkedin.com/company/parcelbio',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'gene-therapy',
#    'biotech',
#    'healthcare',
#    'drug-delivery',
#    'therapeutics',
#    'San Francisco'],
#   'Email': ['founders@parcelbio.com']},
#  {'URL': 'https://www.ycombinator.com/companies/k-scale-labs',
#   'Company': 'K-Scale Labs',
#   'Founders': ['Benjamin Bolte', 'Pawel Budzianowski', 'Matthew Freed'],
#   'LinkedIn': 'https://www.linkedin.com/company/kscale/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'machine-learning',
#    'robotics',
#    'consumer',
#    'New York'],
#   'Email': ['ben@kscale.dev']},
#  {'URL': 'https://www.ycombinator.com/companies/marr-labs',
#   'Company': 'Marr Labs',
#   'Founders': ['Dave Grannan', 'Han Shu'],
#   'LinkedIn': 'https://www.linkedin.com/company/marrlabs',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'ai',
#    'ai-assistant',
#    'San Francisco'],
#   'Email': ['hello@marrlabs.com']},
#  {'URL': 'https://www.ycombinator.com/companies/forge-rewards',
#   'Company': 'Forge Rewards',
#   'Founders': ['Ethan Chang', 'Isaac Kan'],
#   'LinkedIn': 'https://linkedin.com/company/forgerewards',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'fintech', 'food-tech', 'ai', 'San Francisco'],
#   'Email': ['founders@forgerewards.com']},
#  {'URL': 'https://www.ycombinator.com/companies/fancave',
#   'Company': 'FanCave',
#   'Founders': ['Luke Bogus', 'Nick Siscoe'],
#   'LinkedIn': 'https://www.linkedin.com/company/fancave/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'marketplace',
#    'sports-tech',
#    'consumer',
#    'entertainment'],
#   'Email': ['hello@fancave.me']},
#  {'URL': 'https://www.ycombinator.com/companies/retailready',
#   'Company': 'RetailReady',
#   'Founders': ['Elle Smyth', 'Sarah Hamer'],
#   'LinkedIn': 'https://www.linkedin.com/company/retailreadyai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'b2b',
#    'compliance',
#    'logistics',
#    'supply-chain',
#    'ai'],
#   'Email': ['founders@retailreadyai.com']},
#  {'URL': 'https://www.ycombinator.com/companies/million',
#   'Company': 'Million',
#   'Founders': ['Aiden Bai', 'Nisarg Patel', 'John Yang'],
#   'LinkedIn': 'https://linkedin.com/in/aidenbai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'open-source',
#    'web-development',
#    'ai-assistant',
#    'ml',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/nowhouse',
#   'Company': 'NowHouse',
#   'Founders': ['Dhaval Gajiwala'],
#   'LinkedIn': 'https://www.linkedin.com/company/nowhouseio/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'fintech',
#    'saas',
#    'enterprise',
#    'infrastructure'],
#   'Email': ['dhaval@nowhouse.io']},
#  {'URL': 'https://www.ycombinator.com/companies/crux',
#   'Company': 'Crux',
#   'Founders': ['Himank Jain', 'Atharva Padhye', 'Prabhat Singh'],
#   'LinkedIn': 'https://www.linkedin.com/company/getcruxai/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/reprompt',
#   'Company': 'Reprompt',
#   'Founders': ['Lukas Martinelli', 'Rob Balian'],
#   'LinkedIn': 'https://www.linkedin.com/company/99389319/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'aiops',
#    'artificial-intelligence',
#    'developer-tools',
#    'b2b',
#    'api',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/inspectmind-ai',
#   'Company': 'InspectMind AI',
#   'Founders': ['Aakash Prasad', 'Shuangling Yin'],
#   'LinkedIn': 'https://www.linkedin.com/company/inspectmind-ai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'construction',
#    'b2b',
#    'proptech',
#    'ai',
#    'San Francisco'],
#   'Email': ['admin@inspectmind.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/blacksmith',
#   'Company': 'Blacksmith',
#   'Founders': ['Aditya Jayaprakash', 'Aditya Maru', 'Aayush Shah'],
#   'LinkedIn': 'https://www.linkedin.com/company/blacksmithrun/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'b2b',
#    'devops',
#    'cloud-computing',
#    'infrastructure',
#    'San Francisco'],
#   'Email': ['hello@blacksmith.sh']},
#  {'URL': 'https://www.ycombinator.com/companies/crowdvolt',
#   'Company': 'CrowdVolt',
#   'Founders': ['Max Hammer', 'Josh Karol', 'Aria Mohseni'],
#   'LinkedIn': 'https://www.linkedin.com/company/crowdvolt/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'marketplace',
#    'entertainment',
#    'social-network',
#    'music',
#    'ticketing'],
#   'Email': ['founders@crowdvolt.comCrowdVoltFounded',
#    'founders@crowdvolt.com']},
#  {'URL': 'https://www.ycombinator.com/companies/kater-ai',
#   'Company': 'kater.ai',
#   'Founders': ['Yvonne Chou', 'Robin Seitz'],
#   'LinkedIn': 'https://www.linkedin.com/company/kater-ai/?viewAsMember=true',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'analytics',
#    'data-engineering',
#    'San Francisco'],
#   'Email': ['support@kater.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/mathgptpro',
#   'Company': 'MathGPTPro',
#   'Founders': ['Tianwei Yue', 'Qi Lyu'],
#   'LinkedIn': 'https://www.linkedin.com/company/mathgptpro',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'ai-enhanced-learning',
#    'education',
#    'generative-ai',
#    'edtech',
#    'ai',
#    'Santa Clara'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/quivr',
#   'Company': 'Quivr',
#   'Founders': ['Stan Girard', 'Antoine Dewez', 'Brian Laleye'],
#   'LinkedIn': 'https://www.linkedin.com/company/getquivr/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/dragoneye',
#   'Company': 'Dragoneye',
#   'Founders': ['Alex Liao'],
#   'LinkedIn': 'https://linkedin.com/in/alexliaoo',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'computer-vision',
#    'ml',
#    'New York'],
#   'Email': ['alex@dragoneye.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/renderlet',
#   'Company': 'renderlet',
#   'Founders': ['Sean Isom'],
#   'LinkedIn': 'https://www.linkedin.com/company/renderlet',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'design-tools',
#    'data-visualization',
#    'New York'],
#   'Email': ['sean@renderlet.com']},
#  {'URL': 'https://www.ycombinator.com/companies/fume',
#   'Company': 'Fume',
#   'Founders': ['Emre Gucer', 'Metehan Öz'],
#   'LinkedIn': 'https://linkedin.com/in/aegucer',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'b2b',
#    'San Francisco'],
#   'Email': ['emre@fumedev.comFumeFounded', 'emre@fumedev.com']},
#  {'URL': 'https://www.ycombinator.com/companies/numo',
#   'Company': 'Numo',
#   'Founders': ['Derrick Wolbert', 'Reuben Balik', 'Q Carlson'],
#   'LinkedIn': 'https://www.linkedin.com/company/numoinc',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'payments',
#    'compliance',
#    'emerging-markets',
#    'neobank',
#    'San Francisco'],
#   'Email': ['derrick@numohq.com', 'q@numohq.com', 'reuben@numohq.com']},
#  {'URL': 'https://www.ycombinator.com/companies/forge',
#   'Company': 'Forge',
#   'Founders': ['Emir Sahmanovic', 'Haris Sahmanovic'],
#   'LinkedIn': 'https://www.linkedin.com/company/forgehq/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'saas',
#    'b2b',
#    'manufacturing',
#    'supply-chain',
#    'procurement',
#    'San Francisco'],
#   'Email': ['emir@forgehq.com']},
#  {'URL': 'https://www.ycombinator.com/companies/taiki',
#   'Company': 'Taiki',
#   'Founders': ['Richard Zhang', 'Alan Lu'],
#   'LinkedIn': 'https://www.linkedin.com/company/taikiai',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/konstructly',
#   'Company': 'Konstructly',
#   'Founders': ['Stefan Vukcevic', 'John Hesler', 'Dima Mikhailovich'],
#   'LinkedIn': 'https://www.linkedin.com/company/konstructly/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'saas',
#    'construction',
#    'b2b',
#    'enterprise'],
#   'Email': ['stefan@konstructly.com']},
#  {'URL': 'https://www.ycombinator.com/companies/pico',
#   'Company': 'Pico',
#   'Founders': ['Taylor Rogalski', 'Zach Gotsch'],
#   'LinkedIn': 'https://www.linkedin.com/in/zach-gotsch-b90a9011/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'artificial-intelligence', 'consumer'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/granza-bio',
#   'Company': 'Granza Bio',
#   'Founders': ['Ashwin Nandakumar', 'Ashwin Jainarayanan'],
#   'LinkedIn': 'https://www.linkedin.com/company/101140973/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'synthetic-biology',
#    'biotech',
#    'healthcare',
#    'therapeutics',
#    'oncology',
#    'San Francisco'],
#   'Email': ['founders@granzabio.com', 'founders@granzabio.com']},
#  {'URL': 'https://www.ycombinator.com/companies/haplotype-labs',
#   'Company': 'Haplotype Labs',
#   'Founders': ['Mike Polcari'],
#   'LinkedIn': 'https://www.linkedin.com/company/haplotype-labs/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'machine-learning',
#    'saas',
#    'healthcare',
#    'genomics',
#    'ai'],
#   'Email': ['yclaunch@haplotypelabs.com']},
#  {'URL': 'https://www.ycombinator.com/companies/healia',
#   'Company': 'Healia',
#   'Founders': ['Priyang Shah'],
#   'LinkedIn': 'https://www.linkedin.com/company/healia-health',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'b2b', 'healthcare', 'health-insurance', 'ai'],
#   'Email': ['founders@healiahealth.com']},
#  {'URL': 'https://www.ycombinator.com/companies/trueclaim',
#   'Company': 'TrueClaim',
#   'Founders': ['Barbora Howell', 'Bobby Bayer'],
#   'LinkedIn': 'https://www.linkedin.com/company/trytrueclaim',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'saas',
#    'health-tech',
#    'healthcare',
#    'hr-tech',
#    'health-insurance',
#    'San Francisco'],
#   'Email': ['founders@trytrueclaim.com']},
#  {'URL': 'https://www.ycombinator.com/companies/cocrafter',
#   'Company': 'CoCrafter',
#   'Founders': ['Johannes Lutz', 'Philipp Rollwage', 'Annabell V.'],
#   'LinkedIn': 'https://www.linkedin.com/company/cocrafter/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'marketplace', 'construction'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/reform',
#   'Company': 'Reform',
#   'Founders': ['Saif Abuhashish', 'Omar Abuhashish', 'Pradhit Gosula'],
#   'LinkedIn': 'https://www.linkedin.com/company/reformhq',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'saas',
#    'logistics',
#    'supply-chain',
#    'ai',
#    'San Francisco'],
#   'Email': ['founders@reformhq.com']},
#  {'URL': 'https://www.ycombinator.com/companies/piramidal',
#   'Company': 'Piramidal',
#   'Founders': ['Dimitris Fotis Sakellariou', 'Kris Pahuja'],
#   'LinkedIn': 'https://www.linkedin.com/company/piramidalai/about',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'hard-tech',
#    'neurotechnology',
#    'health-tech',
#    'diagnostics',
#    'ai',
#    'San Francisco'],
#   'Email': ['info@piramidal.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/junction-bioscience',
#   'Company': 'Junction Bioscience',
#   'Founders': ['Brian Petkov'],
#   'LinkedIn': 'https://linkedin.com/in/brian-petkov-b2a63680',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'ai-powered-drug-discovery',
#    'biotech',
#    'therapeutics',
#    'drug-discovery',
#    'ai',
#    'San Francisco'],
#   'Email': ['brian@junction.bio']},
#  {'URL': 'https://www.ycombinator.com/companies/oddsview',
#   'Company': 'OddsView',
#   'Founders': ['Davis Tong',
#    'Ajay Koritala',
#    'Akaash Patel',
#    'Anthony Ter-Saakov',
#    'Henri Zhang'],
#   'LinkedIn': 'https://linkedin.com/in/davistong',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'sports-tech', 'consumer', 'New York'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/silogy',
#   'Company': 'SiLogy',
#   'Founders': ['Kay Li', 'Paul Kim'],
#   'LinkedIn': 'https://www.linkedin.com/company/100808053/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'saas',
#    'b2b',
#    'semiconductors',
#    'New York'],
#   'Email': ['paul@silogy.io']},
#  {'URL': 'https://www.ycombinator.com/companies/senso',
#   'Company': 'Senso',
#   'Founders': ['Saroop Bharwani', 'Thomas Nelson'],
#   'LinkedIn': 'https://www.linkedin.com/company/senso.ai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'generative-ai',
#    'saas',
#    'enterprise-software',
#    'conversational-ai'],
#   'Email': ['hello@senso.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/eris-biotech',
#   'Company': 'Eris Biotech',
#   'Founders': ['Rachel Garlick', 'Evita Weagel'],
#   'LinkedIn': 'https://www.linkedin.com/company/eris-biotech/about/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'biotech',
#    'therapeutics',
#    'drug-discovery',
#    'oncology'],
#   'Email': ['founders@erisbio.com']},
#  {'URL': 'https://www.ycombinator.com/companies/powder',
#   'Company': 'Powder',
#   'Founders': ['Kanishk Parashar',
#    'Soo Yung Cho',
#    'David Goerz',
#    'Dominic Tully'],
#   'LinkedIn': 'https://www.linkedin.com/company/powderfinance/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'generative-ai',
#    'b2b',
#    'ai-assistant',
#    'Los Altos'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/openfoundry',
#   'Company': 'OpenFoundry',
#   'Founders': ['Tyler Lehman', 'Arthur Chi'],
#   'LinkedIn': 'https://www.linkedin.com/company/openfoundry/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'b2b',
#    'open-source',
#    'infrastructure',
#    'ai',
#    'San Francisco'],
#   'Email': ['tyler@openfoundry.ai', 'arthur@openfoundry.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/goldenbasis',
#   'Company': 'GoldenBasis',
#   'Founders': ['Grant Ackerman', 'Andrew Wang'],
#   'LinkedIn': 'https://www.linkedin.com/company/goldenbasis',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'api',
#    'enterprise-software',
#    'infrastructure',
#    'operations',
#    'San Francisco'],
#   'Email': ['founders@goldenbasis.com']},
#  {'URL': 'https://www.ycombinator.com/companies/arcane',
#   'Company': 'Arcane',
#   'Founders': ['Rohan Mehta', 'Lucas Switzer'],
#   'LinkedIn': 'https://www.linkedin.com/company/arcaneai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'generative-ai',
#    'consumer',
#    'gaming',
#    'ai',
#    'New York'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/somn',
#   'Company': 'Somn',
#   'Founders': ['Shawn Shivdat', 'Deniz Sert'],
#   'LinkedIn': 'https://www.linkedin.com/company/76534709',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'generative-ai',
#    'b2b',
#    'digital-health',
#    'healthcare',
#    'San Francisco'],
#   'Email': ['shawn@somnapp.com']},
#  {'URL': 'https://www.ycombinator.com/companies/magic-hour',
#   'Company': 'Magic Hour',
#   'Founders': ['Runbo Li', 'David Hu'],
#   'LinkedIn': 'https://www.linkedin.com/company/magichour',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'b2b',
#    'video',
#    'media',
#    'creator-economy',
#    'San Francisco'],
#   'Email': ['founders@magichour.ai', 'founders@magichour.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/ryse',
#   'Company': 'Ryse',
#   'Founders': ['Sean Mitchell', 'Harsh Yadav'],
#   'LinkedIn': 'https://www.linkedin.com/company/ryse-market/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'machine-learning',
#    'marketplace',
#    'b2b',
#    'proptech',
#    'New York'],
#   'Email': ['hello@rysemarket.com']},
#  {'URL': 'https://www.ycombinator.com/companies/lumona',
#   'Company': 'Lumona',
#   'Founders': ['Dylan Walker', 'Qiong Zhou Huang', 'Philena Liu'],
#   'LinkedIn': 'https://www.linkedin.com/company/lumona-ai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'generative-ai',
#    'consumer',
#    'search',
#    'San Francisco'],
#   'Email': ['founders@lumona.ai', 'founders@lumona.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/datacurve',
#   'Company': 'Datacurve',
#   'Founders': ['Serena Ge', 'Charley Lee'],
#   'LinkedIn': 'https://www.linkedin.com/company/datacurveai',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['serena@datacurve.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/marblism',
#   'Company': 'Marblism',
#   'Founders': ['Ulric Musset', 'Cyril Pluche'],
#   'LinkedIn': 'https://linkedin.com/in/ulricmusset',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'generative-ai',
#    'ai-assistant'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/commodityai',
#   'Company': 'CommodityAI',
#   'Founders': ['Philip Koenig, CEO', 'Daniel Cervoni', 'Kyle Franz'],
#   'LinkedIn': 'https://www.linkedin.com/company/commodityai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'b2b',
#    'workflow-automation',
#    'supply-chain',
#    'enterprise-software',
#    'ai',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/veles',
#   'Company': 'Veles',
#   'Founders': ['Simon Ooley', 'Patrick Koperwas'],
#   'LinkedIn': 'https://www.linkedin.com/company/velesinc',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'b2b', 'sales', 'enterprise', 'ai'],
#   'Email': ['founders@getveles.com']},
#  {'URL': 'https://www.ycombinator.com/companies/miden',
#   'Company': 'Miden',
#   'Founders': ['Okiemute Avworhokai', 'Ini Udoh'],
#   'LinkedIn': 'https://www.linkedin.com/company/tyrus-technologies/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'fintech', 'payments', 'b2b', 'apis'],
#   'Email': ['founders@tyrus.io']},
#  {'URL': 'https://www.ycombinator.com/companies/fluently',
#   'Company': 'Fluently',
#   'Founders': ['Yurii Rebryk', 'Stanislav Beliaev'],
#   'LinkedIn': 'https://linkedin.com/company/fluently-ai',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'education', 'saas', 'b2b', 'productivity', 'ai'],
#   'Email': ['yrebryk@getfluently.app']},
#  {'URL': 'https://www.ycombinator.com/companies/basepilot',
#   'Company': 'Basepilot',
#   'Founders': ['Ken Hendricks', 'Pascal Wieler'],
#   'LinkedIn': 'https://www.linkedin.com/company/basepilot/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'saas',
#    'no-code',
#    'automation',
#    'ai-assistant',
#    'San Francisco'],
#   'Email': ['founders@basepilot.com']},
#  {'URL': 'https://www.ycombinator.com/companies/aqua-voice',
#   'Company': 'Aqua Voice',
#   'Founders': ['Finnian Brown', 'Jack McIntire'],
#   'LinkedIn': 'https://linkedin.com/in/finn-brown-3b0b56113',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'documents',
#    'artificial-intelligence',
#    'generative-ai',
#    'nlp',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/onedoc',
#   'Company': 'Onedoc',
#   'Founders': ['Pierre Dorge', 'Titouan Launay', 'Auguste Lefevre'],
#   'LinkedIn': 'https://www.linkedin.com/company/onedoclabs/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'documents', 'developer-tools', 'b2b', 'api'],
#   'Email': ['yc@onedoclabs.com']},
#  {'URL': 'https://www.ycombinator.com/companies/xpay',
#   'Company': 'xPay',
#   'Founders': ['Aniket Gupta', 'Rakshit Bansal'],
#   'LinkedIn': 'https://www.linkedin.com/company/xpay-checkout/?viewAsMember=true',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'payments',
#    'international',
#    'San Francisco'],
#   'Email': ['founders@xpaycheckout.com']},
#  {'URL': 'https://www.ycombinator.com/companies/deepnight',
#   'Company': 'DeepNight',
#   'Founders': ['Lucas Young', 'Thomas Li'],
#   'LinkedIn': 'https://www.linkedin.com/in/lucasdyoung/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'computer-vision',
#    'San Francisco'],
#   'Email': ['thomas@deepnight.ai', 'lucas@deepnight.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/vista-space',
#   'Company': 'Vista Space',
#   'Founders': ['Maxim Kraft', 'Chaitanya Kore', 'Petar Matejic'],
#   'LinkedIn': 'https://linkedin.com/company/vista-space',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'alternative-battery-tech',
#    'space-exploration',
#    'satellites',
#    'energy',
#    'aerospace',
#    'San Francisco'],
#   'Email': ['sales@govista.space', 'sales@govista.space']},
#  {'URL': 'https://www.ycombinator.com/companies/corefin',
#   'Company': 'Corefin',
#   'Founders': ['Hubert Tsen', 'Albert Jo'],
#   'LinkedIn': 'https://www.linkedin.com/company/getcorefin',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'finance',
#    'open-source',
#    'lending',
#    'infrastructure',
#    'San Francisco'],
#   'Email': ['founders@corefin.org']},
#  {'URL': 'https://www.ycombinator.com/companies/ocular-ai',
#   'Company': 'Ocular AI',
#   'Founders': ['Michael Moyo', 'Louis Murerwa'],
#   'LinkedIn': 'https://www.linkedin.com/company/use-ocular',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'generative-ai',
#    'b2b',
#    'productivity',
#    'open-source',
#    'ai',
#    'San Francisco'],
#   'Email': ['founder@useocular.com']},
#  {'URL': 'https://www.ycombinator.com/companies/retell-ai',
#   'Company': 'Retell AI',
#   'Founders': ['Bing Wu', 'Todd Li', 'Evie Wang', 'Weijia Yu', 'Zexia Zhang'],
#   'LinkedIn': 'https://www.linkedin.com/company/98828489',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'b2b',
#    'api',
#    'ai',
#    'conversational-ai',
#    'San Francisco'],
#   'Email': ['founders@re-tell.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/rove',
#   'Company': 'Rove',
#   'Founders': ['Max Morganroth', 'Arhan Chhabra'],
#   'LinkedIn': 'https://www.linkedin.com/company/rovecard/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'fintech', 'consumer', 'travel', 'ai', 'New York'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/camelqa',
#   'Company': 'camelQA',
#   'Founders': ['Illiana Reed', 'Isabella Reed', 'Miguel Salinas'],
#   'LinkedIn': 'https://www.linkedin.com/company/camelqa',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'artificial-intelligence', 'saas', 'Austin'],
#   'Email': ['isabella@camelQA.com']},
#  {'URL': 'https://www.ycombinator.com/companies/spark',
#   'Company': 'Spark',
#   'Founders': ['Julia Wu', 'Tae Kim'],
#   'LinkedIn': 'https://www.linkedin.com/company/sparkhqai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'climate',
#    'energy',
#    'renewable-energy'],
#   'Email': ['founders@sparkhq.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/titan',
#   'Company': 'Titan',
#   'Founders': ['Clayton Gardner', 'Joe Percoco', 'Max Bernardy, CTO'],
#   'LinkedIn': 'https://www.linkedin.com/company/titan-invest',
#   'Season': 'S18',
#   'Other Tags': ['Active', 'fintech', 'saas', 'New York'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/terrakotta',
#   'Company': 'Terrakotta',
#   'Founders': ['Vincent Wilson', 'Kusiima Boswell', 'Gabriel Wilson'],
#   'LinkedIn': 'https://www.linkedin.com/company/terrakotta-ai/about/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'real-estate',
#    'sales',
#    'telecommunications',
#    'home-services',
#    'conversational-ai',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/stacksync',
#   'Company': 'Stacksync',
#   'Founders': ['Ruben Burdin', 'Alexis Favre'],
#   'LinkedIn': 'https://www.linkedin.com/company/stacksyncdata/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'b2b',
#    'api',
#    'crm',
#    'data-engineering',
#    'databases',
#    'San Francisco'],
#   'Email': ['ruben@stacksync.cloud']},
#  {'URL': 'https://www.ycombinator.com/companies/hatchet',
#   'Company': 'Ecliptor',
#   'Founders': ['Andre Fu', 'Nanki Grewal'],
#   'LinkedIn': 'https://www.linkedin.com/company/99437744/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'b2b', 'sales', 'ai', 'San Francisco'],
#   'Email': ['andre@ecliptor.ai', 'andre@ecliptor.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/shepherd',
#   'Company': 'Shepherd',
#   'Founders': ['Mohamed El Mahallawy', 'Justin Levine'],
#   'LinkedIn': 'https://linkedin.com/company/withshepherd',
#   'Season': 'W21',
#   'Other Tags': ['Active', 'construction', 'insurance', 'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/sonauto',
#   'Company': 'Sonauto',
#   'Founders': ['Ryan Tremblay', 'Hayden Housen'],
#   'LinkedIn': 'https://www.linkedin.com/company/sonautoai/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'social', 'music', 'ai', 'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/bitesight',
#   'Company': 'BiteSight',
#   'Founders': ['Lucious McDaniel IV', 'Zac Schulwolf'],
#   'LinkedIn': 'https://www.linkedin.com/company/bitesight-food-delivery/about/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'social-media',
#    'restaurant-tech',
#    'marketing',
#    'New York'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/velorum-therapeutics',
#   'Company': 'Velorum Therapeutics',
#   'Founders': ['Pouya Modareszadeh', 'Parsa Modareszadeh'],
#   'LinkedIn': 'https://www.linkedin.com/company/velorumtx/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'biotech',
#    'healthcare',
#    'therapeutics',
#    'drug-discovery',
#    'oncology',
#    'San Francisco'],
#   'Email': ['info@velorumtx.com']},
#  {'URL': 'https://www.ycombinator.com/companies/zep-ai',
#   'Company': 'Zep AI',
#   'Founders': ['Daniel Chalef'],
#   'LinkedIn': 'https://linkedin.com/in/danielchalef',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/openmart',
#   'Company': 'Openmart',
#   'Founders': ['Richard He', 'Kathryn Wu'],
#   'LinkedIn': 'https://linkedin.com/company/openmartai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'saas',
#    'b2b',
#    'sales',
#    'ai'],
#   'Email': ['founders@openmart.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/triply',
#   'Company': 'Triply',
#   'Founders': ['Peter Wachira', 'Collins Muthinja'],
#   'LinkedIn': 'https://www.linkedin.com/company/tripitaca/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'fintech', 'marketplace', 'saas', 'travel'],
#   'Email': ['founders@triply.co']},
#  {'URL': 'https://www.ycombinator.com/companies/amber-ai',
#   'Company': 'Amber AI',
#   'Founders': ['Oliver Zou', 'Helen Wu'],
#   'LinkedIn': 'https://www.linkedin.com/company/amber-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'b2b',
#    'customer-success',
#    'sales',
#    'customer-service',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/thorntale',
#   'Company': 'thorntale',
#   'Founders': ['Dori Wilson', 'Ellen Hui', 'John Stimac'],
#   'LinkedIn': 'https://www.linkedin.com/company/thorntale/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'saas',
#    'b2b',
#    'productivity',
#    'collaboration',
#    'data-visualization',
#    'San Francisco'],
#   'Email': ['founders@thorntale.com', 'founders@thorntale.com']},
#  {'URL': 'https://www.ycombinator.com/companies/alai',
#   'Company': 'Alai',
#   'Founders': ['Anmol Sood', 'Krishna Gupta'],
#   'LinkedIn': 'https://www.linkedin.com/company/getalai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'generative-ai',
#    'saas',
#    'productivity',
#    'enterprise-software',
#    'ai',
#    'San Francisco'],
#   'Email': ['founders@getalai.com']},
#  {'URL': 'https://www.ycombinator.com/companies/pocketpod',
#   'Company': 'PocketPod',
#   'Founders': ['Ross Cefalu', 'Davis Palmie'],
#   'LinkedIn': 'https://www.linkedin.com/company/pocketpod',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'ai-enhanced-learning',
#    'consumer',
#    'entertainment',
#    'podcasts',
#    'ai',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/brainbase',
#   'Company': 'Brainbase',
#   'Founders': ['Gokhan Egri'],
#   'LinkedIn': 'https://www.linkedin.com/company/usebrainbase',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'generative-ai',
#    'saas',
#    'b2b',
#    'workflow-automation',
#    'San Francisco'],
#   'Email': ['gokhan@usebrainbase.xyz']},
#  {'URL': 'https://www.ycombinator.com/companies/focal',
#   'Company': 'Focal',
#   'Founders': ['Robert Cunningham', 'Felix Wang'],
#   'LinkedIn': 'https://www.linkedin.com/company/focalml/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'consumer',
#    'video',
#    'San Francisco'],
#   'Email': ['founders@focalml.com']},
#  {'URL': 'https://www.ycombinator.com/companies/givefront',
#   'Company': 'Givefront',
#   'Founders': ['Matt Tengtrakool', 'Ethan Sayre'],
#   'LinkedIn': 'https://www.linkedin.com/company/givehq',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@givefront.com']},
#  {'URL': 'https://www.ycombinator.com/companies/cleva',
#   'Company': 'Cleva',
#   'Founders': ['Tolu Alabi, CEO', 'Philip Abel, CTO'],
#   'LinkedIn': 'https://www.linkedin.com/company/cleva-banking/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'fintech',
#    'b2b',
#    'remote-work',
#    'emerging-markets'],
#   'Email': ['contact@getcleva.com']},
#  {'URL': 'https://www.ycombinator.com/companies/oma-care',
#   'Company': 'Oma Care',
#   'Founders': ['Arianna Galbraith', 'James Galbraith'],
#   'LinkedIn': 'https://www.linkedin.com/company/oma-care1/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'consumer-health-services',
#    'health-tech',
#    'healthcare',
#    'health-insurance',
#    'San Francisco'],
#   'Email': ['founders@omacare.com']},
#  {'URL': 'https://www.ycombinator.com/companies/artos',
#   'Company': 'Artos',
#   'Founders': ['Josh Kim', 'Varun Patel'],
#   'LinkedIn': 'https://www.linkedin.com/company/99344183/admin/feed/posts/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@artosai.com']},
#  {'URL': 'https://www.ycombinator.com/companies/model-ml',
#   'Company': 'Model ML',
#   'Founders': ['Arnie Englander', 'Chaz Englander'],
#   'LinkedIn': 'https://linkedin.com/in/arnie-englander',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'saas', 'finance', 'b2b', 'ai'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/betterbasket',
#   'Company': 'BetterBasket',
#   'Founders': ['Leon Zhang', 'Vagelis Viskadouros'],
#   'LinkedIn': 'https://www.linkedin.com/company/98110558',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'b2b',
#    'analytics',
#    'food-&-beverage',
#    'retail',
#    'San Francisco'],
#   'Email': ['founders@betterbasket.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/circleback',
#   'Company': 'Circleback',
#   'Founders': ['Ali Haghani', 'Kevin Jacyna'],
#   'LinkedIn': 'https://linkedin.com/company/circlebackai',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@circleback.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/just-words',
#   'Company': 'just words',
#   'Founders': ['Neha Mittal'],
#   'LinkedIn': 'https://www.linkedin.com/company/justwordsai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'b2b',
#    'productivity',
#    'infrastructure',
#    'San Francisco'],
#   'Email': ['founders@justwords.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/risotto',
#   'Company': 'Risotto',
#   'Founders': ['Aron Solberg', 'Alex Confer', 'Chris Paul'],
#   'LinkedIn': 'https://www.linkedin.com/company/tryrisotto/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'b2b',
#    'compliance',
#    'security',
#    'enterprise',
#    'San Francisco'],
#   'Email': ['founders@tryrisotto.com']},
#  {'URL': 'https://www.ycombinator.com/companies/dianahr',
#   'Company': 'DianaHR',
#   'Founders': ['Upeka Bee', 'Tim Kral'],
#   'LinkedIn': 'https://www.linkedin.com/company/dianahr/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'human-resources',
#    'compliance',
#    'hr-tech',
#    'operations',
#    'San Francisco'],
#   'Email': ['founders@dianahr.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/heartbyte',
#   'Company': 'HeartByte',
#   'Founders': ['Rachel Wang', 'Xinyue Liang'],
#   'LinkedIn': 'https://www.linkedin.com/in/rachelshuyanwang',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'generative-ai',
#    'consumer',
#    'entertainment',
#    'social-media',
#    'San Francisco'],
#   'Email': ['rachel@heartbyte.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/yondu',
#   'Company': 'Yondu',
#   'Founders': ['Michael Chen', 'Tahmid Jamal'],
#   'LinkedIn': 'https://www.linkedin.com/company/yonduai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
# ...
#   'Company': 'Pivot Robots',
#   'Founders': ['Siddharth Girdhar', 'Vignesh Rajmohan'],
#   'LinkedIn': 'https://www.linkedin.com/company/pivot-robots/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'robotics',
#    'industrial'],
#   'Email': ['founders@pivotrobots.com']},
#  {'URL': 'https://www.ycombinator.com/companies/aidy',
#   'Company': 'Aidy',
#   'Founders': ['Max Williamson', 'Peter Crocker', 'Greg Miller'],
#   'LinkedIn': 'https://www.linkedin.com/company/aidygrants/about/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'govtech',
#    'workflow-automation',
#    'climate',
#    'fundraising',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/dgi-apparel',
#   'Company': 'DGI Apparel',
#   'Founders': ['Ian Hinkley', 'Grant Fuhr', 'Daniel Shkreli'],
#   'LinkedIn': 'https://www.linkedin.com/company/dgi-apparel',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'marketplace', 'b2b', 'apparel', 'New York'],
#   'Email': ['ian@dgiapparel.com']},
#  {'URL': 'https://www.ycombinator.com/companies/buster',
#   'Company': 'Buster',
#   'Founders': ['Blake Rouse', 'Dallin Bentley'],
#   'LinkedIn': 'https://www.linkedin.com/company/usebuster/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'generative-ai',
#    'saas',
#    'infrastructure',
#    'ai',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/garage',
#   'Company': 'Garage',
#   'Founders': ['Gwanygha’a Gana', 'Cedric Foudjet'],
#   'LinkedIn': 'https://www.linkedin.com/company/garage-mobility/',
#   'Season': 'S22',
#   'Other Tags': ['Active', 'auto-commerce', 'marketplace', 'transportation'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/mango-health',
#   'Company': 'Mango Health',
#   'Founders': ['Jamison Mercurio', 'Zachary Gittelman'],
#   'LinkedIn': 'https://www.linkedin.com/company/97872692/admin/feed/posts/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'health-insurance',
#    'primary-care',
#    'mental-health',
#    'ai',
#    'San Francisco'],
#   'Email': ['jamie@themangohealth.comMango', 'founders@themangohealth.com']},
#  {'URL': 'https://www.ycombinator.com/companies/ncompass-technologies',
#   'Company': 'nCompass Technologies',
#   'Founders': ['Aditya Rajagopal', 'Diederik Vink'],
#   'LinkedIn': 'https://linkedin.com/company/ncompass-technologies',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'hardware',
#    'open-source',
#    'api',
#    'cloud-computing',
#    'ai'],
#   'Email': ['aditya.rajagopal@ncompass.tech', 'diederik.vink@ncompass.tech']},
#  {'URL': 'https://www.ycombinator.com/companies/pretzel-ai',
#   'Company': 'Pretzel AI',
#   'Founders': ['Prasoon Shukla', 'Ramon Garate'],
#   'LinkedIn': 'https://www.linkedin.com/company/pretzel-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'analytics',
#    'collaboration',
#    'open-source',
#    'data-science'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/apriora',
#   'Company': 'Apriora',
#   'Founders': ['Aaron Wang', 'John Rytel'],
#   'LinkedIn': 'https://www.linkedin.com/company/apriora/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'saas',
#    'b2b',
#    'recruiting',
#    'hr-tech',
#    'San Francisco'],
#   'Email': ['founders@apriora.ai',
#    'founders@apriora.ai',
#    'founders@apriora.ai',
#    'founders@apriora.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/malibou',
#   'Company': 'malibou',
#   'Founders': ['Maxence Drummond', 'Alexandre Pernin'],
#   'LinkedIn': 'https://www.linkedin.com/company/malibou-hr/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'b2b', 'productivity', 'hr-tech', 'payroll', 'smb'],
#   'Email': ['maxence.drummond@malibou.co']},
#  {'URL': 'https://www.ycombinator.com/companies/quary',
#   'Company': 'Quary',
#   'Founders': ['Benjamin King', 'Louis Jordan'],
#   'LinkedIn': 'https://www.linkedin.com/company/quarylabs',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'analytics',
#    'data-science',
#    'data-engineering',
#    'ai'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/hemingway',
#   'Company': 'Hemingway',
#   'Founders': ['Rohit Chaparala', 'Sam Detjen'],
#   'LinkedIn': 'https://www.linkedin.com/company/hemingway-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'saas',
#    'scheduling',
#    'dental',
#    'ai',
#    'San Francisco'],
#   'Email': ['rohit@hemingwayai.co']},
#  {'URL': 'https://www.ycombinator.com/companies/tile',
#   'Company': 'Tile',
#   'Founders': ['Jenica Zhong', 'Jessica Fang'],
#   'LinkedIn': 'https://www.linkedin.com/company/102820110/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'saas',
#    'analytics',
#    'big-data',
#    'operations',
#    'New York'],
#   'Email': ['jenica@tile.sh']},
#  {'URL': 'https://www.ycombinator.com/companies/adagy-robotics',
#   'Company': 'Adagy Robotics',
#   'Founders': ['Rosalind Shinkle', 'Kathleen Brandes'],
#   'LinkedIn': 'https://www.linkedin.com/company/adagy-robotics',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'robotics',
#    'logistics',
#    'manufacturing',
#    'New York'],
#   'Email': ['founders@adagyrobotics.com', 'founders@adagyrobotics.com']},
#  {'URL': 'https://www.ycombinator.com/companies/momentic',
#   'Company': 'Momentic',
#   'Founders': ['Wei-Wei Wu', 'Jeff An'],
#   'LinkedIn': 'https://www.linkedin.com/company/momentic-ai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'b2b',
#    'devops',
#    'ai',
#    'San Francisco'],
#   'Email': ['founders@momentic.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/reducto',
#   'Company': 'Reducto',
#   'Founders': ['Adit Abraham', 'Raunak Chowdhuri'],
#   'LinkedIn': 'https://www.linkedin.com/company/reducto-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@reducto.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/vectorview',
#   'Company': 'Vectorview',
#   'Founders': ['Emil Fröberg', 'Lukas Petersson'],
#   'LinkedIn': 'https://www.linkedin.com/company/98949870',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@vectorview.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/maia',
#   'Company': 'Maia',
#   'Founders': ['Claire Wiley', 'Ralph Ma'],
#   'LinkedIn': 'https://linkedin.com/company/ourmaia',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['hello@ourmaia.com']},
#  {'URL': 'https://www.ycombinator.com/companies/precip',
#   'Company': 'Precip',
#   'Founders': ['Jesse Vollmar', 'Michael Asher', 'Sam Pierce Lolla'],
#   'LinkedIn': 'https://linkedin.com/in/vollmarj',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'consumer', 'climate', 'api', 'agriculture', 'ai'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/tracecat',
#   'Company': 'Tracecat',
#   'Founders': ['Chris Lo', 'Daryl Lim'],
#   'LinkedIn': 'https://www.linkedin.com/company/tracecat-ai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'workflow-automation',
#    'cybersecurity',
#    'monitoring',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/kabilah',
#   'Company': 'Kabilah',
#   'Founders': ['Sarah Raza', 'Muhammad Umar Nadeem'],
#   'LinkedIn': 'https://www.linkedin.com/company/kabilah/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'health-tech',
#    'digital-health',
#    'healthcare',
#    'ai',
#    'Stanford'],
#   'Email': ['founders@kabilah.com', 'founders@kabilah.com']},
#  {'URL': 'https://www.ycombinator.com/companies/sonia',
#   'Company': 'Sonia',
#   'Founders': ['Chris Aeberli', 'Dustin Klebe', 'Lukas Wolf'],
#   'LinkedIn': 'https://www.linkedin.com/company/sonia-health/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'healthcare',
#    'mental-health',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/maihem',
#   'Company': 'MAIHEM',
#   'Founders': ['Max Ahrens', 'Eduardo Candela'],
#   'LinkedIn': 'https://www.linkedin.com/company/maihem/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'generative-ai',
#    'machine-learning',
#    'b2b',
#    'trust-&-safety',
#    'ai',
#    'San Francisco'],
#   'Email': ['contact@maihem.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/ion-design',
#   'Company': 'ion design',
#   'Founders': ['Samraaj Bath', 'Samuel Barnholdt'],
#   'LinkedIn': 'https://www.linkedin.com/company/ion-dot-design',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'design-tools',
#    'web-development',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/duckie',
#   'Company': 'Duckie',
#   'Founders': ['Valerie Li', 'Joel Ritossa'],
#   'LinkedIn': 'https://www.linkedin.com/company/duckie-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@duckie.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/happenstance',
#   'Company': 'Happenstance',
#   'Founders': ['Alex Teichman'],
#   'LinkedIn': 'https://linkedin.com/in/alexteichman',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'artificial-intelligence'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/ubicloud',
#   'Company': 'Ubicloud',
#   'Founders': ['Umur Cubukcu', 'Ozgun Erdogan', 'Daniel Farina'],
#   'LinkedIn': 'https://www.linkedin.com/company/ubicloud',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'b2b',
#    'open-source',
#    'cloud-computing',
#    'infrastructure',
#    'databases',
#    'San Francisco'],
#   'Email': ['founders@ubicloud.com']},
#  {'URL': 'https://www.ycombinator.com/companies/greptile',
#   'Company': 'Greptile',
#   'Founders': ['Daksh Gupta', 'Soohoon Choi', 'Vaishant Kameswaran'],
#   'LinkedIn': 'https://linkedin.com/company/greptile',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'ai',
#    'San Francisco'],
#   'Email': ['daksh@greptile.com']},
#  {'URL': 'https://www.ycombinator.com/companies/heypurple',
#   'Company': 'HeyPurple',
#   'Founders': ['Aditya Ganapathi', 'Ryan Ali', 'Josh Passell'],
#   'LinkedIn': 'https://www.linkedin.com/company/heypurple?trk=public_profile_experience-item_profile-section-card_image-click',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'real-estate',
#    'proptech',
#    'conversational-ai',
#    'ai-assistant',
#    'San Francisco'],
#   'Email': ['founders@purplepill.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/ego',
#   'Company': 'ego',
#   'Founders': ['Vishnu Hari', 'Peggy Wang'],
#   'LinkedIn': 'https://www.linkedin.com/company/egolive/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/leya',
#   'Company': 'Leya',
#   'Founders': ['Max Junestrand', 'August Erséus', 'Sigge Labor'],
#   'LinkedIn': 'https://www.linkedin.com/company/leyalaw/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'generative-ai',
#    'legaltech'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/scritch',
#   'Company': 'Scritch',
#   'Founders': ['Claire Lee', 'Rachel Lee'],
#   'LinkedIn': 'https://www.linkedin.com/company/100475282/admin/feed/posts/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'consumer-health-services',
#    'health-tech',
#    'b2b',
#    'healthcare',
#    'ai',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/radmate-ai',
#   'Company': 'RadMate AI',
#   'Founders': ['Mohamed Khalifa', 'Adam Skrocki'],
#   'LinkedIn': 'https://www.linkedin.com/company/radmate-ai',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'saas',
#    'digital-health',
#    'enterprise-software',
#    'ai-assistant',
#    'San Francisco'],
#   'Email': ['founders@radmate.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/ssoready',
#   'Company': 'ssoReady',
#   'Founders': ["Ned O'Leary", 'Ulysse Carion'],
#   'LinkedIn': 'https://linkedin.com/in/nedoleary',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'saas',
#    'security',
#    'open-source',
#    'api',
#    'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/relari',
#   'Company': 'Relari',
#   'Founders': ['Yi Zhang', 'Pasquale Antonante'],
#   'LinkedIn': 'https://www.linkedin.com/company/relari',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@relari.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/drymerge',
#   'Company': 'DryMerge',
#   'Founders': ['Edward Frazer', 'Samuel Brashears'],
#   'LinkedIn': 'https://www.linkedin.com/company/98894763/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'saas',
#    'api',
#    'automation',
#    'infrastructure',
#    'San Francisco'],
#   'Email': ['founders@drymerge.com', 'founders@drymerge.com']},
#  {'URL': 'https://www.ycombinator.com/companies/navier-ai',
#   'Company': 'Navier AI',
#   'Founders': ['Cameron Flannery', 'Evan Kay'],
#   'LinkedIn': 'https://www.linkedin.com/company/navier-ai/about/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['founders@navier.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/upsolve-ai',
#   'Company': 'Upsolve AI',
#   'Founders': ['Ka Ling Wu', 'Serguei Balanovich'],
#   'LinkedIn': 'https://www.linkedin.com/company/upsolveai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'developer-tools',
#    'generative-ai',
#    'analytics',
#    'data-visualization',
#    'ai',
#    'San Francisco'],
#   'Email': ['kaling.wu@upsolve.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/sciphi',
#   'Company': 'SciPhi',
#   'Founders': ['Owen Colegrove'],
#   'LinkedIn': 'https://www.linkedin.com/company/sciphi-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'developer-tools',
#    'infrastructure',
#    'ai'],
#   'Email': ['founders@sciphi.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/agenthub',
#   'Company': 'AgentHub',
#   'Founders': ['Max Brodeur-Urbas', 'Rahul Behal'],
#   'LinkedIn': 'https://www.linkedin.com/company/agenthubai/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': ['feedback@agenthub.dev']},
#  {'URL': 'https://www.ycombinator.com/companies/driver-ai',
#   'Company': 'Driver AI',
#   'Founders': ['Adam Tilton', 'Daniel Hensley'],
#   'LinkedIn': 'https://www.linkedin.com/company/driver-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'saas', 'b2b', 'ai', 'Austin'],
#   'Email': ['adam.tilton@driverai.com']},
#  {'URL': 'https://www.ycombinator.com/companies/lantern',
#   'Company': 'Lantern',
#   'Founders': ['Bastien Beurier', 'Guillaume Lachaud'],
#   'LinkedIn': 'https://www.linkedin.com/in/bastienbeurier/',
#   'Season': 'S19',
#   'Other Tags': ['Inactive', 'artificial-intelligence', 'San Francisco'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/danswer',
#   'Company': 'Danswer',
#   'Founders': ['Yuhong Sun', 'Chris Weaver'],
#   'LinkedIn': 'https://www.linkedin.com/in/danswer-ai/',
#   'Season': 'W24',
#   'Other Tags': ['Active'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/yenmo',
#   'Company': 'Yenmo',
#   'Founders': ['Ashutosh Purohit', 'Aryan Agarwal'],
#   'LinkedIn': 'https://www.linkedin.com/company/yenmo-in/',
#   'Season': 'W24',
#   'Other Tags': ['Active', 'fintech', 'lending', 'consumer-finance'],
#   'Email': []},
#  {'URL': 'https://www.ycombinator.com/companies/governgpt',
#   'Company': 'GovernGPT',
#   'Founders': ['Mamal Amini', 'Oliver Walerys'],
#   'LinkedIn': 'https://www.linkedin.com/company/93647085/',
#   'Season': 'W24',
#   'Other Tags': ['Active',
#    'artificial-intelligence',
#    'finance',
#    'b2b',
#    'investing',
#    'ai'],
#   'Email': ['mamal@governgpt.ai']},
#  {'URL': 'https://www.ycombinator.com/companies/stitch-technologies',
#   'Company': 'Stitch Technologies',
#   'Founders': ['Till Kern', 'Yuriy Oparenko'],
#   'LinkedIn': 'https://www.linkedin.com/company/stitch-tech',
#   'Season': 'W24',
#   'Other Tags': ['Inactive', 'developer-tools', 'saas'],
#   'Email': []}]

# %%
## Making a copy in case to alter the copy instead of original
copy_list = list_founders

# %%
founder_df = pd.DataFrame(copy_list)

# %%
founder_df
# Out:
#                                                    URL              Company  \
# 0       https://www.ycombinator.com/companies/alacrity             Alacrity
# 1      https://www.ycombinator.com/companies/parcelbio            ParcelBio
# 2    https://www.ycombinator.com/companies/k-scale-...         K-Scale Labs
# 3      https://www.ycombinator.com/companies/marr-labs            Marr Labs
# 4    https://www.ycombinator.com/companies/forge-re...        Forge Rewards
# ..                                                 ...                  ...
# 235      https://www.ycombinator.com/companies/lantern              Lantern
# 236      https://www.ycombinator.com/companies/danswer              Danswer
# 237        https://www.ycombinator.com/companies/yenmo                Yenmo
# 238    https://www.ycombinator.com/companies/governgpt            GovernGPT
# 239  https://www.ycombinator.com/companies/stitch-t...  Stitch Technologies
#
#                                               Founders  \
# 0                         [Omar Draz, Anderthan Hsieh]
# 1                      [David Weinberg, Chris Carlson]
# 2    [Benjamin Bolte, Pawel Budzianowski, Matthew F...
# 3                              [Dave Grannan, Han Shu]
# 4                             [Ethan Chang, Isaac Kan]
# ..                                                 ...
# 235               [Bastien Beurier, Guillaume Lachaud]
# 236                         [Yuhong Sun, Chris Weaver]
# 237                  [Ashutosh Purohit, Aryan Agarwal]
# 238                      [Mamal Amini, Oliver Walerys]
# 239                        [Till Kern, Yuriy Oparenko]
#
#                                              LinkedIn Season  \
# 0    https://www.linkedin.com/company/100487698/admin    W24
# 1          https://www.linkedin.com/company/parcelbio    W24
# 2            https://www.linkedin.com/company/kscale/    W24
# 3           https://www.linkedin.com/company/marrlabs    W24
# 4           https://linkedin.com/company/forgerewards    W24
# ..                                                ...    ...
# 235       https://www.linkedin.com/in/bastienbeurier/    S19
# 236           https://www.linkedin.com/in/danswer-ai/    W24
# 237        https://www.linkedin.com/company/yenmo-in/    W24
# 238        https://www.linkedin.com/company/93647085/    W24
# 239      https://www.linkedin.com/company/stitch-tech    W24
#
#                                             Other Tags  \
# 0    [Active, identity, fraud-prevention, fraud-det...
# 1    [Active, gene-therapy, biotech, healthcare, dr...
# 2    [Active, artificial-intelligence, machine-lear...
# 3    [Active, artificial-intelligence, ai, ai-assis...
# 4      [Active, fintech, food-tech, ai, San Francisco]
# ..                                                 ...
# 235  [Inactive, artificial-intelligence, San Franci...
# 236                                           [Active]
# 237       [Active, fintech, lending, consumer-finance]
# 238  [Active, artificial-intelligence, finance, b2b...
# 239                  [Inactive, developer-tools, saas]
#
#                            Email
# 0    [founders@joinalacrity.com]
# 1       [founders@parcelbio.com]
# 2               [ben@kscale.dev]
# 3           [hello@marrlabs.com]
# 4    [founders@forgerewards.com]
# ..                           ...
# 235                           []
# 236                           []
# 237                           []
# 238         [mamal@governgpt.ai]
# 239                           []
#
# [240 rows x 7 columns]

# %%
def non_duplicates(dataframe):
    """Removes duplicates and return a cleaned dataframe

    Param (dataframe)-->DF pandas
    """
    duplicates = dataframe.duplicated('Company', keep=False)
    cleaned_dataframe = dataframe.drop_duplicates('Company', keep = 'first')
    return cleaned_dataframe

# %%
cleaned_founder_df = non_duplicates(founder_df)

# %%
complete_df = pd.merge(df, cleaned_founder_df, on='Company', how='outer')

# %%
complete_df
# Out:
#                      Company                         Location  \
# 0                   Alacrity           San Francisco, CA, USA
# 1                  ParcelBio           San Francisco, CA, USA
# 2               K-Scale Labs                New York, NY, USA
# 3                  Marr Labs           San Francisco, CA, USA
# 4              Forge Rewards           San Francisco, CA, USA
# ..                       ...                              ...
# 245                    Yenmo             Bengaluru, KA, India
# 246                GovernGPT              Toronto, ON, Canada
# 247      Stitch Technologies  London, England, United Kingdom
# 248                TableFlow                              NaN
# 249  Double – Coding Copilot                              NaN
#
#                                            Description             web_name  \
# 0        AI Based Account Takeover Prevention Platform             alacrity
# 1                       Next-generation mRNA medicines            parcelbio
# 2                          Open-source humanoid robots         k-scale-labs
# 3    AI-voice agents that are indistinguishable fro...            marr-labs
# 4    All-in-one operations software to power restau...        forge-rewards
# ..                                                 ...                  ...
# 245                  Secured consumer lending in India                yenmo
# 246                   AI Back Office for Private Funds            governgpt
# 247                                                  -  stitch-technologies
# 248                                                NaN                  NaN
# 249                                                NaN                  NaN
#
#                                                    URL  \
# 0       https://www.ycombinator.com/companies/alacrity
# 1      https://www.ycombinator.com/companies/parcelbio
# 2    https://www.ycombinator.com/companies/k-scale-...
# 3      https://www.ycombinator.com/companies/marr-labs
# 4    https://www.ycombinator.com/companies/forge-re...
# ..                                                 ...
# 245        https://www.ycombinator.com/companies/yenmo
# 246    https://www.ycombinator.com/companies/governgpt
# 247  https://www.ycombinator.com/companies/stitch-t...
# 248      https://www.ycombinator.com/companies/inquery
# 249       https://www.ycombinator.com/companies/double
#
#                                               Founders  \
# 0                         [Omar Draz, Anderthan Hsieh]
# 1                      [David Weinberg, Chris Carlson]
# 2    [Benjamin Bolte, Pawel Budzianowski, Matthew F...
# 3                              [Dave Grannan, Han Shu]
# 4                             [Ethan Chang, Isaac Kan]
# ..                                                 ...
# 245                  [Ashutosh Purohit, Aryan Agarwal]
# 246                      [Mamal Amini, Oliver Walerys]
# 247                        [Till Kern, Yuriy Oparenko]
# 248                      [Mitch Patin, Eric Ciminelli]
# 249              [Wesley Yue, Gonzalo Espinoza Graham]
#
#                                              LinkedIn Season  \
# 0    https://www.linkedin.com/company/100487698/admin    W24
# 1          https://www.linkedin.com/company/parcelbio    W24
# 2            https://www.linkedin.com/company/kscale/    W24
# 3           https://www.linkedin.com/company/marrlabs    W24
# 4           https://linkedin.com/company/forgerewards    W24
# ..                                                ...    ...
# 245        https://www.linkedin.com/company/yenmo-in/    W24
# 246        https://www.linkedin.com/company/93647085/    W24
# 247      https://www.linkedin.com/company/stitch-tech    W24
# 248      https://www.linkedin.com/company/tableflowhq    W23
# 249        https://www.linkedin.com/company/double-ai    W23
#
#                                             Other Tags  \
# 0    [Active, identity, fraud-prevention, fraud-det...
# 1    [Active, gene-therapy, biotech, healthcare, dr...
# 2    [Active, artificial-intelligence, machine-lear...
# 3    [Active, artificial-intelligence, ai, ai-assis...
# 4      [Active, fintech, food-tech, ai, San Francisco]
# ..                                                 ...
# 245       [Active, fintech, lending, consumer-finance]
# 246  [Active, artificial-intelligence, finance, b2b...
# 247                  [Inactive, developer-tools, saas]
# 248  [Active, artificial-intelligence, developer-to...
# 249  [Active, developer-tools, saas, chatbot, enter...
#
#                            Email
# 0    [founders@joinalacrity.com]
# 1       [founders@parcelbio.com]
# 2               [ben@kscale.dev]
# 3           [hello@marrlabs.com]
# 4    [founders@forgerewards.com]
# ..                           ...
# 245                           []
# 246         [mamal@governgpt.ai]
# 247                           []
# 248                           []
# 249                           []
#
# [250 rows x 10 columns]

# %%
complete_df.to_csv('YCscrape.csv')

# %%
# User Search Function
# want to show:
# company, location, description, web_name, founders, linkedin, email, season, other tags

def search():
    """ Input company name to output information including
    [company, location, description, web_name, founders, linkedin,
    email, season, other tags]

    information is validated within function

    param("any company name")--> string type
    """
    company_name = input("Please input a company name that you would like to see information about. ").lower()
    valid_names = [name.lower() for name in complete_df['Company']]
    while company_name in valid_names:
        return complete_df[complete_df['Company'].str.lower() == company_name]
    else:
        return "We cannot find your company. Please try again."

search()
# Out:
# Please input a company name that you would like to see information about. Alacrity
#     Company                Location  \
# 0  Alacrity  San Francisco, CA, USA
#
#                                      Description  web_name  \
# 0  AI Based Account Takeover Prevention Platform  alacrity
#
#                                               URL  \
# 0  https://www.ycombinator.com/companies/alacrity
#
#                        Founders  \
# 0  [Omar Draz, Anderthan Hsieh]
#
#                                            LinkedIn Season  \
# 0  https://www.linkedin.com/company/100487698/admin    W24
#
#                                           Other Tags  \
# 0  [Active, identity, fraud-prevention, fraud-det...
#
#                          Email
# 0  [founders@joinalacrity.com]

# %%
driver.quit()
